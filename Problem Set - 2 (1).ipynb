# %% [markdown]
# # QUESTION 1
# # Consider the following Python module:
#
# # a = 0
#
# # def b():
# # global a
# # a = c(a)
#
# # def c(a):
# # return a + 2
#
# # After importing the module into the interpreter, you execute:
#
# # >>> b()
# # >>> b()
# # >>> b()
# # >>> a
# # ?
#
# # What value is displayed when the last expression (a) is evaluated? Explain your answer by indicating what happens in every executed statement.

# %% [markdown]
# # ANSWER 1 -

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2

b()
b()
b()
print(a)
# Out:
# 6

# %% [markdown]
# # The final output we get after running the code is 6.
#
# # Reason:
# # Inside function b(), 'global a' makes the variable 'a' global variable
# # so when c(a) is called the value of the global variable 'a' is passed as a parameter in the function
# # and the function returns a+2 and assigns it to 'a'
# # this cycle repeats 3 times and hence the value of global variable 'a' by the end of execution is '6'

# %% [markdown]
# # Question 2
# # Function fileLength(), given to you, takes the name of a file as input and returns
# # the length of the file:
# # >>> fileLength('midterm.py') 284
# # >>> fileLength('idterm.py')
# # Traceback (most recent call last):
# # File "<pyshell#34>", line 1, in < module >
# # fileLength('idterm.py')
# # File "/Users/me/midterm.py", line 3, in fileLength
# # infile = open(filename)
# # FileNotFoundError: [Errno 2] No such file or directory:
# # 'idterm.py'
#
# # As shown above, if the file cannot be found by the interpreter or if it cannot be read as a text file, an exception will be raised. Modify function fileLength() so that a friendly message is printed instead:
#
# # >>> fileLength('midterm.py')
# # 358
# # >>> fileLength('idterm.py')
# # File idterm.py not found
#
# # ANSWER 2 -

# %%
import os
#Defining a function filelength
def fileLength(fileName):
    
    #checking the location of file
    
    if( not os.path.isfile(fileName)):
        print("File "+fileName+" not found")
    else:
        infile = open(fileName)
        lines = 0
        words = 0
        while True:
            lines = lines+1
            line = infile.readline() 
            words = words+len(line)
            if not line: 
                break
       
        print('The number of words in the file:',words)

# calling function

fileLength('q3.txt')
fileLength('abc.py')
# Out:
# The number of words in the file: 384
# File abc.py not found

# %% [markdown]
# # QUESTION 3
# # Write a class named Marsupial that can be used as shown below
# # >>> m = Marsupial()
# # >>> m.put_in_pouch('doll')
# # >>> m.put_in_pouch('firetruck')
# # >>> m.put_in_pouch('kitten')
# # >>> m.pouch_contents()
# # ['doll', 'firetruck', 'kitten']
# # Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# # attributes of Marsupial and also:
# # a. extends the Marsupial __init__ constructor to take, as input, the
# # coordinates x and y of the Kangaroo object,
# # b. supports method jump that takes number values dx and dy as input and
# # moves the kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# # c. overloads the __str__ operator so it behaves as shown below.
# # >>> k = Kangaroo(0,0)
# # >>> print(k)
# # I am a Kangaroo located at coordinates (0,0)
# # >>> k.put_in_pouch('doll')
# # >>> k.put_in_pouch('firetruck')
# # >>> k.put_in_pouch('kitten')
# # >>> k.pouch_contents()
# # ['doll', 'firetruck', 'kitten']
# # >>> k.jump(1,0)
# # >>> k.jump(1,0)
# # >>> print(k)
# # I am a Kangaroo located at coordinates (3,0)
# # ANSWER 3 -

# %%
# Creating a class Marsupial
class Marsupial:
    
    def __init__(self):
        self.pouch = []
    
    def put_in_pouch(self,thing):
        self.pouch.append(thing)
    
    def pouch_contents(self):
        print(self.pouch)


# m = Marsupial()
# m.put_in_pouch('doll')
# m.put_in_pouch('firetruck')
# m.put_in_pouch('kitten')
# m.pouch_contents()

# Creating a child class

class Kangaroo(Marsupial):
    
    def __init__(self,x,y):
        self.x = x
        self.y = y
        Marsupial.__init__(self)
    
    def jump(self,dx,dy):
        self.x = self.x+dx
        self.y = self.y+dy
    
    def __str__(self):
        return "I am a Kangaroo located at coordinates ("+str(self.x)+","+str(self.y)+")"
    
# Calling a function

k = Kangaroo(0,0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# # Question 4
# # Implement a new GUI class App that combines user-defined tkinter widget classes Calculator and Mortgage displayed below: (This question can be done using a .py file
#
# # ANSWER 4 -

# %%
# I took a little help from geeks for geeks to develop the calculator.The code provided at geeks for geeks was missing 
# a lot of functionalities
# I added functions for squareroot,square,memory plus ,memory minus,memory recall and memory clear
# The code provided would clear the screen which is not an expected behaviour for a calculator
# So I modified the code to behave like a real calculator

from tkinter import *
import math


class Calculator(Frame):

    def press(self,num):
        self.expression = self.expression + str(num)
        self.equation.set(self.expression)

    # Function to evaluate the final self.expression

    def equalpress(self):
        print(self.expression)
        try:

            total = str(eval(self.expression))

            self.equation.set(total)

            self.expression = total

        except:

            self.equation.set(" error ")
            # self.expression = ""

    def plusequalpress(self):
        try:

            total = str(eval(self.expression))

            self.equation.set(total)

            self.expression = total+'+'

        except:

            self.equation.set(" error ")
            self.expression = ""

    def rootpress(self):

        try:

            total = str(math.sqrt(eval(self.expression)))

            self.equation.set(total)

            self.expression = total

        except:

            self.equation.set(" error ")
            self.expression = ""

    def squarepress(self):
        try:

            total = str(eval(self.expression)**2)

            self.equation.set(total)

            # self.expression = ""

        except:

            self.equation.set(" error ")
            self.expression = ""
    
    def MCpress(self):
        self.Memeory=0

    def Mpluspress(self):
        try:

            total = eval(self.expression)
            self.Memeory = self.Memeory + total
            self.expression = ''  

        except:
            self.equation.set(" error ")
            self.expression = ""

    def Mminuspress(self):
        try:
            total = eval(self.expression)
            self.Memeory = self.Memeory - total
            self.expression = ''  

        except:
            self.equation.set(" error ")
            self.expression = ""

    def MRpress(self):
        try:
            self.equation.set(self.Memeory)

        except:
            self.equation.set(" error ")
            self.expression = ""

    def clear(self):
        self.expression = ""
        self.equation.set("")

    def __init__(self, parent):
        Frame.__init__(self, parent)
        self.expression = ""
        self.Memeory = 0
        self.configure(background="white", padx=10, pady=10)
        self.makeWidgets()

    def makeWidgets(self):
        self.equation = StringVar()

        self.expression_field = Entry(self, textvariable=self.equation)
        self.expression_field.grid(columnspan=4, ipadx=52,)

        self.equation.set('enter your self.expression')

        button1 = Button(self, text=' 1 ', fg='black', bg='white',
                         command=lambda: self.press(1), height=1, width=5)
        button1.grid(row=6, column=0)

        button2 = Button(self, text=' 2 ', fg='black', bg='white',
                         command=lambda: self.press(2), height=1, width=5)
        button2.grid(row=6, column=1)

        button3 = Button(self, text=' 3 ', fg='black', bg='white',
                         command=lambda: self.press(3), height=1, width=5)
        button3.grid(row=6, column=2)

        button4 = Button(self, text=' 4 ', fg='black', bg='white',
                         command=lambda: self.press(4), height=1, width=5)
        button4.grid(row=5, column=0)

        button5 = Button(self, text=' 5 ', fg='black', bg='white',
                         command=lambda: self.press(5), height=1, width=5)
        button5.grid(row=5, column=1)

        button6 = Button(self, text=' 6 ', fg='black', bg='white',
                         command=lambda: self.press(6), height=1, width=5)
        button6.grid(row=5, column=2)

        button7 = Button(self, text=' 7 ', fg='black', bg='white',
                         command=lambda: self.press(7), height=1, width=5)
        button7.grid(row=4, column=0)

        button8 = Button(self, text=' 8 ', fg='black', bg='white',
                         command=lambda: self.press(8), height=1, width=5)
        button8.grid(row=4, column=1)

        button9 = Button(self, text=' 9 ', fg='black', bg='white',
                         command=lambda: self.press(9), height=1, width=5)
        button9.grid(row=4, column=2)

        button0 = Button(self, text=' 0 ', fg='black', bg='white',
                         command=lambda: self.press(0), height=1, width=5)
        button0.grid(row=7, column=0)

        plus = Button(self, text=' + ', fg='black', bg='white',
                      command=lambda: self.press("+"), height=1, width=5)
        plus.grid(row=3, column=3)

        minus = Button(self, text=' - ', fg='black', bg='white',
                       command=lambda: self.press("-"), height=1, width=5)
        minus.grid(row=4, column=3)

        multiply = Button(self, text=' * ', fg='black', bg='white',
                          command=lambda: self.press("*"), height=1, width=5)
        multiply.grid(row=5, column=3)

        divide = Button(self, text=' / ', fg='black', bg='white',
                        command=lambda: self.press("/"), height=1, width=5)
        divide.grid(row=6, column=3)

        equal = Button(self, text=' = ', fg='black', bg='white',
                       command=self.equalpress, height=1, width=5)
        equal.grid(row=7, column=3)

        plusequal = Button(self, text=' += ', fg='black', bg='white',
                       command=self.plusequalpress, height=1, width=5)
        plusequal.grid(row=7, column=2)

        clear = Button(self, text='Clear', fg='black', bg='white',
                       command=self.clear, height=1, width=5)
        clear.grid(row=3, column=0)

        Decimal = Button(self, text='.', fg='black', bg='white',
                         command=lambda: self.press('.'), height=1, width=5)
        Decimal.grid(row=7, column=1)

        root = Button(self, text='root', fg='black', bg='white',
                       command=self.rootpress, height=1, width=5)
        root.grid(row=3, column=1)

        square = Button(self, text='Square', fg='black', bg='white',
                       command=self.squarepress, height=1, width=5)
        square.grid(row=3, column=2)

        MC = Button(self, text='MC', fg='black', bg='white',
                       command=self.MCpress, height=1, width=5)
        MC.grid(row=1, column=0)

        MPlus = Button(self, text='M+', fg='black', bg='white',
                       command=self.Mpluspress, height=1, width=5)
        MPlus.grid(row=1, column=1)

        MR = Button(self, text='MR', fg='black', bg='white',
                       command=self.MRpress, height=1, width=5)
        MR.grid(row=1, column=2)

        MMinus = Button(self, text='M-', fg='black', bg='white',
                       command=self.Mminuspress, height=1, width=5)
        MMinus.grid(row=1, column=3)

class Mortgage(Frame):

    def __init__(self, parent):
        Frame.__init__(self,parent)
        self.configure(background="white", padx=10, pady=10)
        self.makeWidgets()

    def makeWidgets(self):
        Label(self, bg="white", text="Loan Amount").grid(row=1,
                                               column=1, sticky=W)
        Label(self, bg="white", text="Annual Interest Rate").grid(row=2,
                                                        column=1, sticky=W)
        Label(self, bg="white", text="Loan Terms").grid(row=3,
                                                   column=1, sticky=W)
        Label(self, bg="white", text="Monthly Payment").grid(row=4,
                                                   column=1, sticky=W)
        Label(self, bg="white", text="Total Payment").grid(row=5,
                                                 column=1, sticky=W)

        # for taking inputs
        self.annualInterestRateVar = StringVar()
        Entry(self, textvariable=self.annualInterestRateVar,
              justify=RIGHT).grid(row=1, column=2)
        self.numberOfYearsVar = StringVar()

        Entry(self, textvariable=self.numberOfYearsVar,
              justify=RIGHT).grid(row=2, column=2)
        self.loanAmountVar = StringVar()

        Entry(self, textvariable=self.loanAmountVar,
              justify=RIGHT).grid(row=3, column=2)
        self.monthlyPaymentVar = StringVar()
        lblMonthlyPayment = Label(self, bg="white", textvariable=self.monthlyPaymentVar).grid(row=4,
                                                                                    column=2, sticky=E)

        self.totalPaymentVar = StringVar()
        lblTotalPayment = Label(self, bg="white", textvariable=self.totalPaymentVar).grid(row=5,
                                                                                column=2, sticky=E)

        # create the button
        btComputePayment = Button(self, bg="white", text="Compute Payment",
                                  command=self.computePayment).grid(
            row=6, column=1, sticky=E)
        # self.mainloop()  # Create an event loop

    def computePayment(self):

        monthlyPayment = self.getMonthlyPayment(
            float(self.loanAmountVar.get()),
            float(self.annualInterestRateVar.get()) / 1200,
            int(self.numberOfYearsVar.get()))

        self.monthlyPaymentVar.set(format(monthlyPayment, '10.2f'))
        totalPayment = float(self.monthlyPaymentVar.get()) * \
            12 * int(self.numberOfYearsVar.get())

        self.totalPaymentVar.set(format(totalPayment, '10.2f'))

    def getMonthlyPayment(self, loanAmount, monthlyInterestRate, numberOfYears):
        # compute the monthly payment.
        monthlyPayment = loanAmount * monthlyInterestRate / (1
                                                             - 1 / (1 + monthlyInterestRate) ** (numberOfYears * 12))
        return monthlyPayment
        # root = Tk()  # create the widget


root = Tk()
root.configure(background="white", padx=10, pady=10) 
root.title("Calculator")  # Set title
mortgage = Mortgage(root)
calculator = Calculator(root)
calculator.pack(side=RIGHT)
mortgage.pack(side=LEFT)
root.mainloop()
print("end")
# Out:
# end

# %% [markdown]
# # QUESTION 5
# # Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:
# # x = {
# # 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# # 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑�
# # Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.
# # >>> collatz(1)
# # 1
# # >>> collatz(10)
# # 10
# # 5
# # 1
# # 6
# # 8
# # 4
# # 2
# # 1
#
# # ANSWER 5 -

# %%
# Defining a function collatz

def collatz(x):
    while(x!=1):
        print(x)
        if(x%2==0):
            x = int(x/2)
        else:
            x = (3*x)+1
    print(1)
    
#Calling a function
collatz(1)

collatz(10)
# Out:
# 1
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # QUESTION 6
# # Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.
# # >>> binary(0)
# # 0
# # >>> binary(1)
# # 1
# # >>> binary(3)
# # 11
# # >>> binary(9)
# # 1001
#
# # ANSWER 6 -

# %%
# Defining a function 

def binary(x):
    if(x==0):
        print(0)
        return
    binary = "" 
    while(x>0):
        binary = binary+str(x%2)
        x = x//2
    print(binary)
    
# calling the function

binary(0)
binary(1)
binary(3)
binary(9)
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# # QUESTION 7
# # Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.
# # >>> infile = open('w3c.html')
# # >>> content = infile.read()
# # >>> infile.close()
# # >>> hp = HeadingParser()
# # >>> hp.feed(content)
# # W3C Mission
#   # Principles
#   # ANSWER 7 -

# %%
# Importing module


from html.parser import HTMLParser


# Creating a class HeadingParser


class HeadingParser(HTMLParser):
    
    # defining function
    
    def __init__(self):
        self.start_tag = ""
        HTMLParser.__init__(self)
        
        
    #defining function
    

    def handle_starttag(self, tag, attrs):
        self.start_tag = tag
        
    
    #defining function
    
    
    def handle_data(self, data):
        if(self.start_tag=='h1'):
            print(data)
        if(self.start_tag=='h2'):
            print("\t"+data)
        if(self.start_tag=='h3'):
            print("\t\t"+data)
        if(self.start_tag=='h4'):
            print("\t\t\t"+data)
        if(self.start_tag=='h5'):
            print("\t\t\t\t"+data)
        if(self.start_tag=='h6'):
            print("\t\t\t\t\t\t"+data)
        self.start_tag = ""

infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
# 	Principles

# %% [markdown]
# # QUESTION 8
# # Implement recursive function webdir() that takes as input: a URL (as a string) and non-negative integers depth and indent. Your function should visit every web page reachable from the starting URL web page in depth clicks or less, and print each web page's URL. As shown below, indentation, specified by indent, should be used to indicate the depth of a URL.
# # >>> webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html' , 2, 0) http://reed.cs.depaul.edu/lperkovic/csc242/test1.html http://reed.cs.depaul.edu/lperkovic/csc242/test2.html         http://reed.cs.depaul.edu/lperkovic/csc242/test4.html     http://reed.cs.depaul.edu/lperkovic/csc242/test3.html         http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
#
# # ANSWER 8 -

# %%
from html.parser import HTMLParser
import requests
class UrlParser(HTMLParser):
 
    def __init__(self):
        self.urls = []
        HTMLParser.__init__(self)

    def handle_starttag(self, tag, attrs):
        self.start_tag = tag
        if(tag=='a'):
            for name,value in attrs:
                if(name=='href'):
                    self.urls.append(value)

    def getUrls(self):
        return self.urls


def webdir(url,depth,indent):

    if(depth==-1):
        return
    
    tabs = ""
    for i in range(indent):
        tabs = tabs+"\t"
    print(tabs+url)
    
    urlParser = UrlParser()
    html = requests.get(url)
    urlParser.feed(html.text)
    urls = urlParser.getUrls()
    
    # print(urls)
    for _url in urls:
        if(not 'http' in _url):
            _url = url+_url
        webdir(_url,depth-1,indent+1)

webdir("https://webscraper.io/test-sites/e-commerce/allinone",2,0)
# Out:
# https://webscraper.io/test-sites/e-commerce/allinone
# 	https://webscraper.io/test-sites/e-commerce/allinone/
# 		https://webscraper.io/test-sites/e-commerce/allinone//
# 		https://webscraper.io/test-sites/e-commerce/allinone/#page-top
# 		https://webscraper.io/test-sites/e-commerce/allinone//
# 		https://webscraper.io/test-sites/e-commerce/allinone//cloud-scraper
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-079b6445f6d8> in <module>
#      39         webdir(_url,depth-1,indent+1)
#      40
# ---> 41 webdir("https://webscraper.io/test-sites/e-commerce/allinone",2,0)
#
# <ipython-input-11-079b6445f6d8> in webdir(url, depth, indent)
#      37         if(not 'http' in _url):
#      38             _url = url+_url
# ---> 39         webdir(_url,depth-1,indent+1)
#      40
#      41 webdir("https://webscraper.io/test-sites/e-commerce/allinone",2,0)
#
# ...

# %% [markdown]
# # QUESTION 9
# # Write SQL queries on the below database table that return:
# # a) All the temperature data.
# # b) All the cities, but without repetition
# # c) All the records for India.
# # d) All the Fall records.
# # e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
# # f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
# # g) The total annual rainfall for Cairo.
# # h) The total rainfall for each season

# %% [markdown]
# # ANSWER 9
# # a) SELECT Temprature from Weather
# # b) SELECT DISTINCT City from Weather
# # c) SELECT * from Weather WHERE Country = 'India'
# # d) SELECT * from Weather WHERE Season = 'Fall'
# # e) SELECT City, Country, Season from Weather where Rainfall BETWEEN 200 And 400
# # f) SELECT City, Country from Weather where Season = 'Fall' And Temprature >20 ORDER BY Temprature ASC
# # g) SELECT Sum(Rainfall) FROM Weather where City='Cairo';
# # h) SELECT Season,Sum(Rainfall) FROM Weather GROUP BY Season;

# %% [markdown]
# # QUESTION 10
# # . Suppose list words is defined as follows:
# # >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# # Write list comprehension expressions that use list words and generate the following lists:
# # a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# # b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# # c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list words).
# # d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list words, where each list contains the word in uppercase and lowercase and the length of the word.)
# # e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'] (the list of words in list words containing 4 or more characters.)

# %% [markdown]
# # ANSWER 10

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
'the', 'lazy', 'dog']

# Solution for part a
a = [ word.upper() for word in words]
print(a)

# Solution for part b
b = [ word.lower() for word in words]
print(b)

# Solution for part c
c = [ len(word) for word in words]
print(c)

# Solution for part d
d = [ [word.upper(),word.lower(), len(word)] for word in words]
print(d)

# Solution for part e
e = [ word for word in words if len(word)>=4]
print(e)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
